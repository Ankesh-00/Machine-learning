# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pt

# %%
df=pd.read_csv("Ames_Housing_Data.csv")

# %%
df
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0     526301100           20        RL         141.0     31770   Pave   NaN
# 1     526350040           20        RH          80.0     11622   Pave   NaN
# 2     526351010           20        RL          81.0     14267   Pave   NaN
# 3     526353030           20        RL          93.0     11160   Pave   NaN
# 4     527105010           60        RL          74.0     13830   Pave   NaN
# ...         ...          ...       ...           ...       ...    ...   ...
# 2925  923275080           80        RL          37.0      7937   Pave   NaN
# 2926  923276100           20        RL           NaN      8885   Pave   NaN
# 2927  923400125           85        RL          62.0     10441   Pave   NaN
# 2928  924100070           20        RL          77.0     10010   Pave   NaN
# 2929  924151050           60        RL          74.0      9627   Pave   NaN
#
# ...

# %%
df.head(10)
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
# 2  526351010           20        RL          81.0     14267   Pave   NaN
# 3  526353030           20        RL          93.0     11160   Pave   NaN
# 4  527105010           60        RL          74.0     13830   Pave   NaN
# 5  527105030           60        RL          78.0      9978   Pave   NaN
# 6  527127150          120        RL          41.0      4920   Pave   NaN
# 7  527145080          120        RL          43.0      5005   Pave   NaN
# 8  527146030          120        RL          39.0      5389   Pave   NaN
# 9  527162130           60        RL          60.0      7500   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# ...

# %%
df.describe()
# Out:
#                 PID  MS SubClass  Lot Frontage       Lot Area  Overall Qual  \
# count  2.930000e+03  2930.000000   2440.000000    2930.000000   2930.000000
# mean   7.144645e+08    57.387372     69.224590   10147.921843      6.094881
# std    1.887308e+08    42.638025     23.365335    7880.017759      1.411026
# min    5.263011e+08    20.000000     21.000000    1300.000000      1.000000
# 25%    5.284770e+08    20.000000     58.000000    7440.250000      5.000000
# 50%    5.354536e+08    50.000000     68.000000    9436.500000      6.000000
# 75%    9.071811e+08    70.000000     80.000000   11555.250000      7.000000
# max    1.007100e+09   190.000000    313.000000  215245.000000     10.000000
#
#        Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  \
# count   2930.000000  2930.000000     2930.000000   2907.000000   2929.000000
# mean       5.563140  1971.356314     1984.266553    101.896801    442.629566
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2930 non-null   int64
#  1   MS SubClass      2930 non-null   int64
#  2   MS Zoning        2930 non-null   object
#  3   Lot Frontage     2440 non-null   float64
#  4   Lot Area         2930 non-null   int64
#  5   Street           2930 non-null   object
#  6   Alley            198 non-null    object
#  7   Lot Shape        2930 non-null   object
#  8   Land Contour     2930 non-null   object
#  9   Utilities        2930 non-null   object
#  10  Lot Config       2930 non-null   object
#  11  Land Slope       2930 non-null   object
#  12  Neighborhood     2930 non-null   object
#  13  Condition 1      2930 non-null   object
#  14  Condition 2      2930 non-null   object
#  15  Bldg Type        2930 non-null   object
# ...

# %% [markdown]
# # Explorary data analysis

# %%
df["Lot Frontage"].unique()
# Out:
# array([141.,  80.,  81.,  93.,  74.,  78.,  41.,  43.,  39.,  60.,  75.,
#         nan,  63.,  85.,  47., 152.,  88., 140., 105.,  65.,  70.,  26.,
#         21.,  53.,  24., 102.,  98.,  83.,  94.,  95.,  90.,  79., 100.,
#         44., 110.,  61.,  36.,  67., 108.,  59.,  92.,  58.,  56.,  73.,
#         72.,  84.,  76.,  50.,  55.,  68., 107.,  25.,  30.,  57.,  40.,
#         77., 120., 137.,  87., 119.,  64.,  96.,  71.,  69.,  52.,  51.,
#         54.,  86., 124.,  82.,  38.,  48.,  89.,  66.,  45.,  35., 129.,
#         31.,  42.,  28.,  99., 104.,  97., 103.,  34., 117., 149., 122.,
#         62., 174., 106., 112.,  32., 115., 128.,  91.,  33., 121., 144.,
#        130., 109., 150., 113., 125., 101.,  46., 114., 135., 136.,  37.,
#         22., 313.,  49., 123., 160., 195., 118., 134., 182., 116., 138.,
#        155., 126., 200., 168., 111., 131., 153., 133.])

# %%
print(df["Garage Cars"].isnull().sum() )
# Out:
# 1

# %%
df2=df.drop(['PID','Alley','Pool QC','Fence','Misc Feature'], axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 76 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MS SubClass      2930 non-null   int64
#  1   MS Zoning        2930 non-null   object
#  2   Lot Frontage     2440 non-null   float64
#  3   Lot Area         2930 non-null   int64
#  4   Street           2930 non-null   object
#  5   Lot Shape        2930 non-null   object
#  6   Land Contour     2930 non-null   object
#  7   Utilities        2930 non-null   object
#  8   Lot Config       2930 non-null   object
#  9   Land Slope       2930 non-null   object
#  10  Neighborhood     2930 non-null   object
#  11  Condition 1      2930 non-null   object
#  12  Condition 2      2930 non-null   object
#  13  Bldg Type        2930 non-null   object
#  14  House Style      2930 non-null   object
#  15  Overall Qual     2930 non-null   int64
# ...

# %%
#categorical data
categorical_cols = ['MS Zoning', 'Street', 'Lot Shape', 'Land Contour','Sale Type','Sale Condition','Paved Drive','Garage Cond','Garage Qual','Garage Finish','Garage Type','Fireplace Qu','Functional','Kitchen Qual','Electrical','Central Air',
                    'Heating QC','Heating','BsmtFin Type 2','BsmtFin Type 1','Bsmt Exposure','Bsmt Cond','Bsmt Qual','Foundation','Exter Cond','Exter Qual','Mas Vnr Type','Exterior 2nd','Exterior 1st','Roof Matl','Roof Style','House Style','Bldg Type','Condition 2','Condition 1','Neighborhood','Land Slope','Lot Config','Utilities'] 
from sklearn.preprocessing import LabelEncoder
# instantiate labelencoder object
le = LabelEncoder()
# apply le on categorical feature columns
df2[categorical_cols] = df2[categorical_cols].apply(lambda a: le.fit_transform(a))

# %%
df2
# Out:
#       MS SubClass  MS Zoning  Lot Frontage  Lot Area  Street  Lot Shape  \
# 0              20          5         141.0     31770       1          0
# 1              20          4          80.0     11622       1          3
# 2              20          5          81.0     14267       1          0
# 3              20          5          93.0     11160       1          3
# 4              60          5          74.0     13830       1          0
# ...           ...        ...           ...       ...     ...        ...
# 2925           80          5          37.0      7937       1          0
# 2926           20          5           NaN      8885       1          0
# 2927           85          5          62.0     10441       1          3
# 2928           20          5          77.0     10010       1          3
# 2929           60          5          74.0      9627       1          3
#
#       Land Contour  Utilities  Lot Config  Land Slope  ...  Enclosed Porch  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 76 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MS SubClass      2930 non-null   int64
#  1   MS Zoning        2930 non-null   int64
#  2   Lot Frontage     2440 non-null   float64
#  3   Lot Area         2930 non-null   int64
#  4   Street           2930 non-null   int64
#  5   Lot Shape        2930 non-null   int64
#  6   Land Contour     2930 non-null   int64
#  7   Utilities        2930 non-null   int64
#  8   Lot Config       2930 non-null   int64
#  9   Land Slope       2930 non-null   int64
#  10  Neighborhood     2930 non-null   int64
#  11  Condition 1      2930 non-null   int64
#  12  Condition 2      2930 non-null   int64
#  13  Bldg Type        2930 non-null   int64
#  14  House Style      2930 non-null   int64
#  15  Overall Qual     2930 non-null   int64
#  16  Overall Cond     2930 non-null   int64
# ...

# %%
mean_value=df2["Lot Frontage"].mean()

# %%
mean_value
# Out:
# 69.22459016393442

# %%
df2["Lot Frontage"].fillna(value=mean_value, inplace=True)

# %%
df2
# Out:
#       MS SubClass  MS Zoning  Lot Frontage  Lot Area  Street  Lot Shape  \
# 0              20          5     141.00000     31770       1          0
# 1              20          4      80.00000     11622       1          3
# 2              20          5      81.00000     14267       1          0
# 3              20          5      93.00000     11160       1          3
# 4              60          5      74.00000     13830       1          0
# ...           ...        ...           ...       ...     ...        ...
# 2925           80          5      37.00000      7937       1          0
# 2926           20          5      69.22459      8885       1          0
# 2927           85          5      62.00000     10441       1          3
# 2928           20          5      77.00000     10010       1          3
# 2929           60          5      74.00000      9627       1          3
#
#       Land Contour  Utilities  Lot Config  Land Slope  ...  Enclosed Porch  \
# ...

# %%
mean_value=df2["Mas Vnr Area"].mean()
df2["Mas Vnr Area"].fillna(value=df2["Mas Vnr Area"].mean(), inplace=True)

# %%
df2["Garage Cars"].fillna(value=df2["Mas Vnr Area"].mean(), inplace=True)
df2["Garage Area"].fillna(value=df2["Garage Area"].mean(), inplace=True)
df2["Garage Yr Blt"].fillna(value=df2["Garage Yr Blt"].mean(), inplace=True)
df2["Bsmt Half Bath"].fillna(value=df2["Bsmt Half Bath"].mean(), inplace=True)
df2["Bsmt Full Bath"].fillna(value=df2["Bsmt Full Bath"].mean(), inplace=True)
df2["Total Bsmt SF"].fillna(value=df2["Total Bsmt SF"].mean(), inplace=True)
df2["Bsmt Unf SF"].fillna(value=df2["Bsmt Unf SF"].mean(), inplace=True)
df2["BsmtFin SF 2"].fillna(value=df2["BsmtFin SF 2"].mean(), inplace=True)
df2["BsmtFin SF 1"].fillna(value=df2["BsmtFin SF 1"].mean(), inplace=True)

# %%
df2.isnull().sum()
# Out:
# MS SubClass       0
# MS Zoning         0
# Lot Frontage      0
# Lot Area          0
# Street            0
#                  ..
# Mo Sold           0
# Yr Sold           0
# Sale Type         0
# Sale Condition    0
# SalePrice         0
# Length: 76, dtype: int64

# %%
df2.corr(method="pearson")
# Out:
#                 MS SubClass  MS Zoning  Lot Frontage  Lot Area    Street  \
# MS SubClass        1.000000  -0.017259     -0.392019 -0.204613  0.002338
# MS Zoning         -0.017259   1.000000     -0.065371 -0.010588  0.121061
# Lot Frontage      -0.392019  -0.065371      1.000000  0.365503 -0.047568
# Lot Area          -0.204613  -0.010588      0.365503  1.000000 -0.133966
# Street             0.002338   0.121061     -0.047568 -0.133966  1.000000
# ...                     ...        ...           ...       ...       ...
# Mo Sold            0.000350  -0.025028      0.010177  0.003859  0.016919
# Yr Sold           -0.017905  -0.024299     -0.006921 -0.023085 -0.018328
# Sale Type          0.034401   0.069416     -0.041126 -0.000118  0.012254
# Sale Condition    -0.019344  -0.016172      0.031491  0.019079  0.016678
# SalePrice         -0.085092  -0.137472      0.340751  0.266549  0.059519
#
#                 Lot Shape  Land Contour  Utilities  Lot Config  Land Slope  \
# ...

# %%
sns.heatmap(df2.corr(method="pearson"))
# Out:
# <Axes: >

# %%
x=df2.iloc[:,0:75]

# %%
x
# Out:
#       MS SubClass  MS Zoning  Lot Frontage  Lot Area  Street  Lot Shape  \
# 0              20          5     141.00000     31770       1          0
# 1              20          4      80.00000     11622       1          3
# 2              20          5      81.00000     14267       1          0
# 3              20          5      93.00000     11160       1          3
# 4              60          5      74.00000     13830       1          0
# ...           ...        ...           ...       ...     ...        ...
# 2925           80          5      37.00000      7937       1          0
# 2926           20          5      69.22459      8885       1          0
# 2927           85          5      62.00000     10441       1          3
# 2928           20          5      77.00000     10010       1          3
# 2929           60          5      74.00000      9627       1          3
#
#       Land Contour  Utilities  Lot Config  Land Slope  ...  Open Porch SF  \
# ...

# %%
y=df2.iloc[:,[75]]

# %%
y
# Out:
#       SalePrice
# 0        215000
# 1        105000
# 2        172000
# 3        244000
# 4        189900
# ...         ...
# 2925     142500
# 2926     131000
# 2927     132000
# 2928     170000
# 2929     188000
#
# [2930 rows x 1 columns]

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=101)

# %% [markdown]
# # Model Selection

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred
# Out:
# array([ 241195.70313481,  208265.47309026,  243107.45947768,
#         221814.8872287 ,  266138.1088417 ,   92400.83080504,
#         114992.39039743,   84722.57378687,  228427.19018964,
#         138211.53145199,  113807.51911036,  329199.95344565,
#         106114.08435847,  167653.45967759,  188241.160342  ,
#          99381.73572683,  228830.50562344,  154661.96756562,
#         179770.51012241,  219645.61341843,  212978.85146914,
#         138473.09547874,  278152.11199078,  126582.02788571,
#         226557.62915347,  186879.29424869,  227277.39282386,
#         114530.47898039,  121844.02605712,  227209.33359007,
#         107652.98413341,  191637.36228683,  200152.20582969,
#         296450.21815874,  207892.73879996,  256601.50217254,
#         259229.02606452,  113542.08097195,  304535.56314302,
#         118262.84265186,  166689.46336917,  199646.5045656 ,
#         197666.37972142,  309377.06238819,  166833.73479277,
# ...

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,accuracy_score

# %%
from sklearn import metrics as ms

# %%
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rsme=np.sqrt(mse)

# %%
mae
# Out:
# 20192.347339864606

# %%
mse
# Out:
# 1668609695.0111015

# %%
rsme
# Out:
# 40848.6192546468
